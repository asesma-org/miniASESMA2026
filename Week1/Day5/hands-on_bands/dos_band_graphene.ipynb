# %% [markdown]
# # Band structure and DOS for graphene

# %% [markdown]
# Ref:
#     https://wiki.fysik.dtu.dk/ase/ase/dft/kpoints.html

# %% [markdown]
# ## To run this tutorial we need to
#  - import QEpy
#  - Use ASE to generate molecular structures
#
# ### To run this tutorial in google colab click the following link :
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/asesma-org/miniASESMA2026/blob/main/Week1/Day5/hands-on_bands/dos_band_graphene.ipynb)

# %%
## Uncomment the following lines for Colab. IMPORTANT NOTE: install first qepy and then dftpy
# !pip install qepy f90wrap==0.2.16

# %%
# !python -m pip install "git+https://github.com/Quantum-MultiScale/DFTpy.git@dev"

# %%
## Uncomment these lines for Colab
# additional_files = {
#     'C.pbe-rrkjus.UPF' : 'https://raw.githubusercontent.com/asesma-org/miniASESMA2026/refs/heads/main/Week1/Day5/hands-on_bands/C.pbe-rrkjus.UPF',
# }
# from dftpy.formats import download_files
# download_files(additional_files)

# %%
import numpy as np
from qepy.calculator import QEpyCalculator
from qepy.io import QEInput

# %%
from ase.io.trajectory import Trajectory
from ase.lattice.hexagonal import Graphene
from ase import Atoms
import matplotlib.pyplot as plt

# %%
qe_options = {
    '&control': {
        'calculation': "'scf'",
        'prefix': "'tmp'",
        'pseudo_dir': "'./'"},
    '&system': {
        'ecutwfc': 20,
        'ecutrho': 200},
    '&electrons': {
        'conv_thr' : 1.0e-8},
     'atomic_species': ['C 12.0107 C.pbe-rrkjus.UPF'],
     'k_points automatic': [' 9 9 1 0 0 0'],
}

# %%
atoms = Graphene('C', latticeconstant={'a':2.46, 'c': 7})

# %%
calc = QEpyCalculator(qe_options=qe_options, logfile='tmp.out')
atoms.calc=calc

# %% [markdown]
# ## Run a ground state calculation

# %%
energy = atoms.get_potential_energy()
efermi = calc.get_fermi_level()
print(efermi)
# Out:
# 1.2286355528583208

# %% [markdown]
# ## DOS with a fine mesh of $k$-points $\in$ FBZ

# %%
qe_options['k_points automatic']= ['12 12 1 0 0 0']
energies, dos =  atoms.calc.get_dos(qe_options, width=0.6)

# %%
plt.plot(energies, dos)
plt.axvline(x=0, ls='--'); plt.xlabel("Energy (eV)"); plt.ylabel("DOS"); 
plt.text(x=-1.5,y=1.5,rotation='vertical',s='Fermi level')
# Out:
# Text(-1.5, 1.5, 'Fermi level')

# %% [markdown]
# ## Band structure with ASE bandpath

# %%
lat = atoms.cell.get_bravais_lattice()
lat.plot_bz(show=True)
print(lat.description())
# Out:
# HEX(a=2.46, c=7)
#   Variant name: HEX
#   Special point names: GMKALH
#   Default path: GMKGALHA,LM,KH
#
#   Special point coordinates:
#     G   0.0000  0.0000  0.0000
#     M   0.5000  0.0000  0.0000
#     K   0.3333  0.3333  0.0000
#     A   0.0000  0.0000  0.5000
#     L   0.5000  0.0000  0.5000
#     H   0.3333  0.3333  0.5000

# %%
path = atoms.cell.bandpath('GKMG',npoints=61)

# %%
qe_options['&system']['nbnd']=6
band = atoms.calc.get_band_structure(qe_options, kpts=path, reference=efermi)
band = band.subtract_reference()

# %%
bp=band.plot()
bp.set_ylim(-20,10)
# Out:
# (-20.0, 10.0)

# %%
fig = plt.figure()
ax = fig.add_axes([.12, .07, .67, .85])

emin = -20.0; emax = 8.0

bands = band.subtract_reference()
bands.plot(ax=ax, emin=emin, emax=emax)

dosax = fig.add_axes([.8, .07, .17, .85])
dosax.plot(dos, energies)
dosax.axhline(y=0, ls=':')

dosax.set_ylim(emin, emax)
dosax.set_xlim(0, None)
dosax.set_yticks([])
dosax.set_xticks([])
dosax.set_xlabel("DOS", fontsize=18);
